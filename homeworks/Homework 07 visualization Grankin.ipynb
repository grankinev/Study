# %%
import pandas as pd
import numpy as np
from matplotlib import pylab as plt
import seaborn as sns
df = pd.read_csv('train.csv')
# Task 1-1
sns.countplot(x = df['AnimalType'])

#Task 1-2
df['OutcomeType'].value_counts().plot('bar')

#Task 1-3

# %%
df
# Out:
#       AnimalID        Name             DateTime      OutcomeType  \
# 0      A671945     Hambone  2014-02-12 18:22:00  Return_to_owner
# 1      A656520       Emily  2013-10-13 12:44:00       Euthanasia
# 2      A686464      Pearce  2015-01-31 12:28:00         Adoption
# 3      A683430         NaN  2014-07-11 19:09:00         Transfer
# 4      A667013         NaN  2013-11-15 12:52:00         Transfer
# 5      A677334        Elsa  2014-04-25 13:04:00         Transfer
# 6      A699218       Jimmy  2015-03-28 13:11:00         Transfer
# 7      A701489         NaN  2015-04-30 17:02:00         Transfer
# 8      A671784        Lucy  2014-02-04 17:17:00         Adoption
# 9      A677747         NaN  2014-05-03 07:48:00         Adoption
# 10     A668402         NaN  2013-12-05 15:50:00         Transfer
# 11     A666320         NaN  2013-11-04 14:48:00         Adoption
# 12     A684601      Rocket  2016-02-03 11:27:00         Adoption
# ...

# %%
sns.countplot(x='SexuponOutcome',data=df)
sns.countplot(x='OutcomeType',data=df)

# %%
sns.barplot(x='SexuponOutcome'.values,y='OutcomeType'.values,data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-f2f05159962c> in <module>()
# ----> 1 sns.barplot(x='SexuponOutcome'.values,y='OutcomeType'.values,data=df)
#
# AttributeError: 'str' object has no attribute 'values'

# %%
sns.barplot(df['OutcomeType'].values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-16450038d3a0> in <module>()
# ----> 1 sns.barplot(df['OutcomeType'].values)
#
# C:\Apps\Anaconda\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# C:\Apps\Anaconda\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
sns.countplot(x='OutcomeType',data=df)

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('data-405-2018-10-03.xml')

# %%
root = tree.getroot()

# %% [raw]
# root[0]
